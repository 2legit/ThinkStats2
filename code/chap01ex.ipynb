# %% [markdown]
# # Examples and Exercises from Think Stats, 2nd Edition
#
# http://thinkstats2.com
#
# Copyright 2016 Allen B. Downey
#
# MIT License: https://opensource.org/licenses/MIT

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/My Drive/ThinkStats2/code/
# Out:
# /content/gdrive/My Drive/ThinkStats2/code

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/ThinkStats2/code

# %%
from __future__ import print_function, division

import nsfg

# %%
dir(nsfg)
# Out:
# ['CleanFemPreg',
#  'CleanFemResp',
#  'MakePregMap',
#  'ReadFemPreg',
#  'ReadFemResp',
#  'ValidatePregnum',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'defaultdict',
#  'division',
#  'main',
#  'np',
#  'print_function',
#  'sys',
#  'thinkstats2']

# %% [markdown]
# ## Examples from Chapter 1
#
# Read NSFG data into a Pandas DataFrame.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
preg = nsfg.ReadFemPreg()
preg.head()
# Out:
#    caseid  pregordr  howpreg_n  howpreg_p  ...  secu_p  sest  cmintvw  totalwgt_lb
# 0       1         1        NaN        NaN  ...       2     9      NaN       8.8125
# 1       1         2        NaN        NaN  ...       2     9      NaN       7.8750
# 2       2         1        NaN        NaN  ...       2    12      NaN       9.1250
# 3       2         2        NaN        NaN  ...       2    12      NaN       7.0000
# 4       2         3        NaN        NaN  ...       2    12      NaN       6.1875
#
# [5 rows x 244 columns]

# %% [markdown]
# Print the column names.

# %%
preg.columns
# Out:
# Index(['caseid', 'pregordr', 'howpreg_n', 'howpreg_p', 'moscurrp', 'nowprgdk',
#        'pregend1', 'pregend2', 'nbrnaliv', 'multbrth',
#        ...
#        'laborfor_i', 'religion_i', 'metro_i', 'basewgt', 'adj_mod_basewgt',
#        'finalwgt', 'secu_p', 'sest', 'cmintvw', 'totalwgt_lb'],
#       dtype='object', length=244)

# %% [markdown]
# Select a single column name.

# %%
preg.columns[1]
# Out:
# 'pregordr'

# %% [markdown]
# Select a column and check what type it is.

# %%
pregordr = preg['pregordr']
type(pregordr)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Print a column.

# %%
pregordr
# Out:
# 0        1
# 1        2
# 2        1
# 3        2
# 4        3
#         ..
# 13588    1
# 13589    2
# 13590    3
# 13591    4
# 13592    5
# Name: pregordr, Length: 13593, dtype: int64

# %% [markdown]
# Select a single element from a column.

# %%
pregordr[0]
# Out:
# 1

# %% [markdown]
# Select a slice from a column.

# %%
pregordr[2:5]
# Out:
# 2    1
# 3    2
# 4    3
# Name: pregordr, dtype: int64

# %% [markdown]
# Select a column using dot notation.

# %%
pregordr = preg.pregordr

# %% [markdown]
# Count the number of times each value occurs.

# %%
preg.outcome.value_counts().sort_index()
# Out:
# 1    9148
# 2    1862
# 3     120
# 4    1921
# 5     190
# 6     352
# Name: outcome, dtype: int64

# %%
x = preg.outcome.value_counts()

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
x
# Out:
# 1    9148
# 4    1921
# 2    1862
# 6     352
# 5     190
# 3     120
# Name: outcome, dtype: int64

# %%
x.sort_index?

# %% [markdown]
# Check the values of another variable.

# %%
preg.birthwgt_lb.value_counts().sort_index()
# Out:
# 0.0        8
# 1.0       40
# 2.0       53
# 3.0       98
# 4.0      229
# 5.0      697
# 6.0     2223
# 7.0     3049
# 8.0     1889
# 9.0      623
# 10.0     132
# 11.0      26
# 12.0      10
# 13.0       3
# 14.0       3
# 15.0       1
# Name: birthwgt_lb, dtype: int64

# %% [markdown]
# Make a dictionary that maps from each respondent's `caseid` to a list of indices into the pregnancy `DataFrame`.  Use it to select the pregnancy outcomes for a single respondent.

# %%
caseid = 10229
preg_map = nsfg.MakePregMap(preg)
indices = preg_map[caseid]
preg.outcome[indices].values
# Out:
# array([4, 4, 4, 4, 4, 4, 1])

# %%
preg_map
# Out:
# defaultdict(list,
#             {1: [0, 1],
#              2: [2, 3, 4],
#              6: [5, 6, 7],
#              7: [8, 9],
#              12: [10],
#              14: [11, 12, 13],
#              15: [14, 15, 16],
#              18: [17, 18],
#              21: [19, 20],
#              23: [21, 22],
#              24: [23, 24, 25],
#              28: [26],
#              31: [27, 28, 29],
#              36: [30, 31],
#              38: [32, 33, 34],
#              39: [35, 36],
#              44: [37, 38, 39, 40],
#              45: [41],
#              46: [42, 43],
#              49: [44, 45, 46, 47],
#              51: [48, 49, 50],
#              52: [51],
#              57: [52, 53, 54],
#              60: [55, 56],
#              63: [57, 58, 59],
#              69: [60],
#              70: [61, 62, 63, 64],
#              71: [65],
#              72: [66, 67],
#              73: [68, 69],
#              77: [70, 71],
#              80: [72, 73, 74, 75, 76],
# ...

# %%
preg_map[10229]
# Out:
# [11093, 11094, 11095, 11096, 11097, 11098, 11099]

# %% [markdown]
# *This will basically get the pregnance outcomes for this caseid's pregancies*

# %%
preg.outcome.value_counts()
# Out:
# 1    9148
# 4    1921
# 2    1862
# 6     352
# 5     190
# 3     120
# Name: outcome, dtype: int64

# %%
preg.outcome.value_counts().sort_index()
# Out:
# 1    9148
# 2    1862
# 3     120
# 4    1921
# 5     190
# 6     352
# Name: outcome, dtype: int64

# %% [markdown]
# *Since value_couts returns a series where the index are the actual values, ordered by number of occurances, we can call sort_index() on the result if we to sort it by the index, i.e. the values. Here the values have meaning, where 1 = live birth, etc*

# %% [markdown]
# ## Exercises

# %% [markdown]
# Select the `birthord` column, print the value counts, and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611933)

# %%
# Solution goes here
preg.birthord.value_counts().sort_index()
# Out:
# 1.0     4413
# 2.0     2874
# 3.0     1234
# 4.0      421
# 5.0      126
# 6.0       50
# 7.0       20
# 8.0        7
# 9.0        2
# 10.0       1
# Name: birthord, dtype: int64

# %% [markdown]
# We can also use `isnull` to count the number of nans.

# %%
preg.birthord.isnull().sum()
# Out:
# 4445

# %% [markdown]
# Select the `prglngth` column, print the value counts, and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
# Solution goes here
x = preg.prglngth.value_counts()

# %%
x.index
# Out:
# Int64Index([39, 40, 38,  9, 41,  6, 37, 13,  4,  8, 35, 36, 42, 17, 11, 30,  5,
#              7, 12,  3, 43, 22, 10, 32, 26,  2, 34, 33, 44, 16, 15, 28, 21, 19,
#             24, 31, 14, 29, 20, 18,  0, 25, 23, 45,  1, 27, 48, 50, 46, 47],
#            dtype='int64')

# %%
x.loc[x.index < 14].sum()
# Out:
# 3522

# %% [markdown]
# To compute the mean of a column, you can invoke the `mean` method on a Series.  For example, here is the mean birthweight in pounds:

# %%
preg.totalwgt_lb.mean()
# Out:
# 7.265628457623368

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
# Solution goes here
preg['totalwgt_kg'] = preg.totalwgt_lb / 2.2
preg.totalwgt_kg.mean()
# Out:
# 3.302558389828807

# %% [markdown]
# `nsfg.py` also provides `ReadFemResp`, which reads the female respondents file and returns a `DataFrame`:

# %%
resp = nsfg.ReadFemResp()

# %% [markdown]
# `DataFrame` provides a method `head` that displays the first five rows:

# %%
resp.sample(3).T
# Out:
#                  3964      1069      1068
# caseid            330         1     11141
# rscrinf             1         1         1
# rdormres            5         5         5
# rostscrn            3         4         5
# rscreenhisp         5         5         5
# ...               ...       ...       ...
# sest               45         9         9
# cmintvw          1231      1231      1229
# cmlstyr          1219      1219      1217
# screentime   15:02:31  19:56:43  15:04:31
# intvlngth     63.0078   67.5638   24.9443
#
# [3087 rows x 3 columns]

# %% [markdown]
# Select the `age_r` column from `resp` and print the value counts.  How old are the youngest and oldest respondents?

# %%
# Solution goes here
resp.age_r.describe()
# Out:
# count    7643.000000
# mean       29.503729
# std         8.433187
# min        15.000000
# 25%        22.000000
# 50%        30.000000
# 75%        37.000000
# max        44.000000
# Name: age_r, dtype: float64

# %% [markdown]
# We can use the `caseid` to match up rows from `resp` and `preg`.  For example, we can select the row from `resp` for `caseid` 2298 like this:

# %%
resp[resp.caseid==2298]

# %% [markdown]
# And we can get the corresponding rows from `preg` like this:

# %%
preg[preg.caseid==2298]

# %% [markdown]
# How old is the respondent with `caseid` 1?

# %%
# Solution goes here
resp.loc[resp.caseid==1, 'age_r']
# Out:
# 1069    44
# Name: age_r, dtype: int64

# %% [markdown]
# What are the pregnancy lengths for the respondent with `caseid` 2298?

# %%
# Solution goes here
preg.loc[preg.caseid==2298, 'prglngth']
# Out:
# 2610    40
# 2611    36
# 2612    30
# 2613    40
# Name: prglngth, dtype: int64

# %% [markdown]
# What was the birthweight of the first baby born to the respondent with `caseid` 5012?

# %%
# Solution goes here
preg.loc[(preg.caseid==5012)]

# %%
# !python chap01ex.py
# Out:
# chap01ex.py: All tests passed... but not really!
